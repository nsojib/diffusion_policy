# %%
import h5py
import numpy as np
import os

def inspect_h5_file(file_path):
    """
    Inspects an HDF5 file and prints its complete structure including
    group names, dataset names, shapes, and data types.

    Args:
        file_path (str): The path to the HDF5 file.
    """
    if not os.path.exists(file_path):
        print(f"Error: File not found at '{file_path}'")
        return

    print(f"--- Inspecting File: {os.path.basename(file_path)} ---")

    try:
        with h5py.File(file_path, 'r') as f:
            # 'r' is the read-only mode
            print_hdf5_item(f, '')
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")

def print_hdf5_item(item, prefix=''):
    """
    Recursively prints the name, shape, and type of items in an HDF5 Group.

    Args:
        item (h5py.File or h5py.Group): The HDF5 item to inspect.
        prefix (str): The prefix for printing, used for indentation.
    """
    for key in sorted(item.keys()):
        # Check if the item is a Group (like a folder)
        if isinstance(item[key], h5py.Group):
            print(f"{prefix}[+] Group: {key}")
            # Recurse into the group
            print_hdf5_item(item[key], prefix + '    ')
            
        # Check if the item is a Dataset (like a file with data)
        elif isinstance(item[key], h5py.Dataset):
            dataset = item[key]
            # LaTex for shape: (d_1, d_2, ..., d_n)
            shape_str = f"Shape: {dataset.shape}" 
            dtype_str = f"Dtype: {dataset.dtype}"
            print(f"{prefix}[-] Dataset: {key} ({shape_str}, {dtype_str})")
        
        # Handle other types if necessary (e.g., soft links)
        else:
            print(f"{prefix}[?] Unknown item: {key}")

# %%
path_to_your_file = '/home/carl_lab/diffusion_policy/pick_100/000000.h5' 
inspect_h5_file(path_to_your_file)
# Out:
# --- Inspecting File: 000000.h5 ---
# [-] Dataset: action (Shape: (71, 8), Dtype: float64)
# [-] Dataset: num_step (Shape: (), Dtype: int64)
# [+] Group: obs
#     [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#     [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#     [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#     [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)

# %%
path_to_your_file = '/home/carl_lab/diffusion_policy/blue_candy_data/demo.hdf5' 
inspect_h5_file(path_to_your_file)
# Out:
# --- Inspecting File: demo.hdf5 ---
# [+] Group: data
#     [+] Group: demo_0
#         [-] Dataset: actions (Shape: (223, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (223, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (223, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (223, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (223, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (223, 7), Dtype: float64)
#     [+] Group: demo_1
#         [-] Dataset: actions (Shape: (278, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (278, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (278, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (278, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (278, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (278, 7), Dtype: float64)
#     [+] Group: demo_10
#         [-] Dataset: actions (Shape: (428, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (428, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (428, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (428, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (428, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (428, 7), Dtype: float64)
#     [+] Group: demo_11
#         [-] Dataset: actions (Shape: (328, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (328, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (328, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (328, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (328, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (328, 7), Dtype: float64)
#     [+] Group: demo_12
#         [-] Dataset: actions (Shape: (247, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (247, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (247, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (247, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (247, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (247, 7), Dtype: float64)
#     [+] Group: demo_13
#         [-] Dataset: actions (Shape: (287, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (287, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (287, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (287, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (287, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (287, 7), Dtype: float64)
#     [+] Group: demo_14
#         [-] Dataset: actions (Shape: (355, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (355, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (355, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (355, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (355, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (355, 7), Dtype: float64)
#     [+] Group: demo_15
#         [-] Dataset: actions (Shape: (246, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (246, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (246, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (246, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (246, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (246, 7), Dtype: float64)
#     [+] Group: demo_16
#         [-] Dataset: actions (Shape: (281, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (281, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (281, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (281, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (281, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (281, 7), Dtype: float64)
#     [+] Group: demo_17
#         [-] Dataset: actions (Shape: (253, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (253, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (253, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (253, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (253, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (253, 7), Dtype: float64)
#     [+] Group: demo_18
#         [-] Dataset: actions (Shape: (227, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (227, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (227, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (227, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (227, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (227, 7), Dtype: float64)
#     [+] Group: demo_19
#         [-] Dataset: actions (Shape: (208, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (208, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (208, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (208, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (208, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (208, 7), Dtype: float64)
#     [+] Group: demo_2
#         [-] Dataset: actions (Shape: (205, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (205, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (205, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (205, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (205, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (205, 7), Dtype: float64)
#     [+] Group: demo_3
#         [-] Dataset: actions (Shape: (288, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (288, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (288, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (288, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (288, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (288, 7), Dtype: float64)
#     [+] Group: demo_4
#         [-] Dataset: actions (Shape: (274, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (274, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (274, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (274, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (274, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (274, 7), Dtype: float64)
#     [+] Group: demo_5
#         [-] Dataset: actions (Shape: (254, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (254, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (254, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (254, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (254, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (254, 7), Dtype: float64)
#     [+] Group: demo_6
#         [-] Dataset: actions (Shape: (271, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (271, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (271, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (271, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (271, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (271, 7), Dtype: float64)
#     [+] Group: demo_7
#         [-] Dataset: actions (Shape: (331, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (331, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (331, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (331, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (331, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (331, 7), Dtype: float64)
#     [+] Group: demo_8
#         [-] Dataset: actions (Shape: (259, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (259, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (259, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (259, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (259, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (259, 7), Dtype: float64)
#     [+] Group: demo_9
#         [-] Dataset: actions (Shape: (250, 7), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: agentview_rgb (Shape: (250, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: ee_states (Shape: (250, 16), Dtype: float64)
#             [-] Dataset: eye_in_hand_rgb (Shape: (250, 240, 320, 3), Dtype: uint8)
#             [-] Dataset: gripper_states (Shape: (250, 1), Dtype: float64)
#             [-] Dataset: joint_states (Shape: (250, 7), Dtype: float64)

# %%
path_to_your_file = 'pick_100.hdf5' 
inspect_h5_file(path_to_your_file)
# Out:
# --- Inspecting File: pick_100.hdf5 ---
# [+] Group: data
#     [+] Group: demo_0
#         [-] Dataset: action (Shape: (71, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)
#     [+] Group: demo_1
#         [-] Dataset: action (Shape: (71, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)
#     [+] Group: demo_10
#         [-] Dataset: action (Shape: (78, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (78, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (78, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (78, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (78, 9), Dtype: float32)
#     [+] Group: demo_11
#         [-] Dataset: action (Shape: (73, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (73, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (73, 9), Dtype: float32)
#     [+] Group: demo_12
#         [-] Dataset: action (Shape: (80, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (80, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (80, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (80, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (80, 9), Dtype: float32)
#     [+] Group: demo_13
#         [-] Dataset: action (Shape: (98, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (98, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (98, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (98, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (98, 9), Dtype: float32)
#     [+] Group: demo_14
#         [-] Dataset: action (Shape: (92, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (92, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (92, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (92, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (92, 9), Dtype: float32)
#     [+] Group: demo_15
#         [-] Dataset: action (Shape: (90, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (90, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (90, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (90, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (90, 9), Dtype: float32)
#     [+] Group: demo_16
#         [-] Dataset: action (Shape: (78, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (78, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (78, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (78, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (78, 9), Dtype: float32)
#     [+] Group: demo_17
#         [-] Dataset: action (Shape: (66, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (66, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (66, 9), Dtype: float32)
#     [+] Group: demo_18
#         [-] Dataset: action (Shape: (68, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (68, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (68, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (68, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (68, 9), Dtype: float32)
#     [+] Group: demo_19
#         [-] Dataset: action (Shape: (78, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (78, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (78, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (78, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (78, 9), Dtype: float32)
#     [+] Group: demo_2
#         [-] Dataset: action (Shape: (103, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (103, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (103, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (103, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (103, 9), Dtype: float32)
#     [+] Group: demo_20
#         [-] Dataset: action (Shape: (88, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (88, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (88, 9), Dtype: float32)
#     [+] Group: demo_21
#         [-] Dataset: action (Shape: (93, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (93, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (93, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (93, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (93, 9), Dtype: float32)
#     [+] Group: demo_22
#         [-] Dataset: action (Shape: (87, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (87, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (87, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (87, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (87, 9), Dtype: float32)
#     [+] Group: demo_23
#         [-] Dataset: action (Shape: (75, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (75, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (75, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (75, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (75, 9), Dtype: float32)
#     [+] Group: demo_24
#         [-] Dataset: action (Shape: (61, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (61, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (61, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (61, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (61, 9), Dtype: float32)
#     [+] Group: demo_25
#         [-] Dataset: action (Shape: (84, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (84, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (84, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (84, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (84, 9), Dtype: float32)
#     [+] Group: demo_26
#         [-] Dataset: action (Shape: (90, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (90, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (90, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (90, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (90, 9), Dtype: float32)
#     [+] Group: demo_27
#         [-] Dataset: action (Shape: (67, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (67, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (67, 9), Dtype: float32)
#     [+] Group: demo_28
#         [-] Dataset: action (Shape: (71, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)
#     [+] Group: demo_29
#         [-] Dataset: action (Shape: (70, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (70, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (70, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (70, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (70, 9), Dtype: float32)
#     [+] Group: demo_3
#         [-] Dataset: action (Shape: (83, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (83, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (83, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (83, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (83, 9), Dtype: float32)
#     [+] Group: demo_30
#         [-] Dataset: action (Shape: (86, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (86, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (86, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (86, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (86, 9), Dtype: float32)
#     [+] Group: demo_31
#         [-] Dataset: action (Shape: (95, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (95, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (95, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (95, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (95, 9), Dtype: float32)
#     [+] Group: demo_32
#         [-] Dataset: action (Shape: (76, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (76, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (76, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (76, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (76, 9), Dtype: float32)
#     [+] Group: demo_33
#         [-] Dataset: action (Shape: (68, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (68, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (68, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (68, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (68, 9), Dtype: float32)
#     [+] Group: demo_34
#         [-] Dataset: action (Shape: (65, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (65, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (65, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (65, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (65, 9), Dtype: float32)
#     [+] Group: demo_35
#         [-] Dataset: action (Shape: (83, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (83, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (83, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (83, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (83, 9), Dtype: float32)
#     [+] Group: demo_36
#         [-] Dataset: action (Shape: (81, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (81, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (81, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (81, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (81, 9), Dtype: float32)
#     [+] Group: demo_37
#         [-] Dataset: action (Shape: (73, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (73, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (73, 9), Dtype: float32)
#     [+] Group: demo_38
#         [-] Dataset: action (Shape: (82, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (82, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (82, 9), Dtype: float32)
#     [+] Group: demo_39
#         [-] Dataset: action (Shape: (71, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)
#     [+] Group: demo_4
#         [-] Dataset: action (Shape: (90, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (90, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (90, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (90, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (90, 9), Dtype: float32)
#     [+] Group: demo_40
#         [-] Dataset: action (Shape: (89, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (89, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (89, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (89, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (89, 9), Dtype: float32)
#     [+] Group: demo_41
#         [-] Dataset: action (Shape: (73, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (73, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (73, 9), Dtype: float32)
#     [+] Group: demo_42
#         [-] Dataset: action (Shape: (71, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)
#     [+] Group: demo_43
#         [-] Dataset: action (Shape: (75, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (75, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (75, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (75, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (75, 9), Dtype: float32)
#     [+] Group: demo_44
#         [-] Dataset: action (Shape: (92, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (92, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (92, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (92, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (92, 9), Dtype: float32)
#     [+] Group: demo_45
#         [-] Dataset: action (Shape: (81, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (81, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (81, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (81, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (81, 9), Dtype: float32)
#     [+] Group: demo_46
#         [-] Dataset: action (Shape: (82, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (82, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (82, 9), Dtype: float32)
#     [+] Group: demo_47
#         [-] Dataset: action (Shape: (66, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (66, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (66, 9), Dtype: float32)
#     [+] Group: demo_48
#         [-] Dataset: action (Shape: (67, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (67, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (67, 9), Dtype: float32)
#     [+] Group: demo_49
#         [-] Dataset: action (Shape: (81, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (81, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (81, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (81, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (81, 9), Dtype: float32)
#     [+] Group: demo_5
#         [-] Dataset: action (Shape: (88, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (88, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (88, 9), Dtype: float32)
#     [+] Group: demo_50
#         [-] Dataset: action (Shape: (81, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (81, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (81, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (81, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (81, 9), Dtype: float32)
#     [+] Group: demo_51
#         [-] Dataset: action (Shape: (102, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (102, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (102, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (102, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (102, 9), Dtype: float32)
#     [+] Group: demo_52
#         [-] Dataset: action (Shape: (74, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (74, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (74, 9), Dtype: float32)
#     [+] Group: demo_53
#         [-] Dataset: action (Shape: (80, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (80, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (80, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (80, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (80, 9), Dtype: float32)
#     [+] Group: demo_54
#         [-] Dataset: action (Shape: (71, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)
#     [+] Group: demo_55
#         [-] Dataset: action (Shape: (71, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)
#     [+] Group: demo_56
#         [-] Dataset: action (Shape: (68, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (68, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (68, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (68, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (68, 9), Dtype: float32)
#     [+] Group: demo_57
#         [-] Dataset: action (Shape: (82, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (82, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (82, 9), Dtype: float32)
#     [+] Group: demo_58
#         [-] Dataset: action (Shape: (68, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (68, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (68, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (68, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (68, 9), Dtype: float32)
#     [+] Group: demo_59
#         [-] Dataset: action (Shape: (79, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (79, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (79, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (79, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (79, 9), Dtype: float32)
#     [+] Group: demo_6
#         [-] Dataset: action (Shape: (73, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (73, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (73, 9), Dtype: float32)
#     [+] Group: demo_60
#         [-] Dataset: action (Shape: (88, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (88, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (88, 9), Dtype: float32)
#     [+] Group: demo_61
#         [-] Dataset: action (Shape: (102, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (102, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (102, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (102, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (102, 9), Dtype: float32)
#     [+] Group: demo_62
#         [-] Dataset: action (Shape: (94, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (94, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (94, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (94, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (94, 9), Dtype: float32)
#     [+] Group: demo_63
#         [-] Dataset: action (Shape: (86, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (86, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (86, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (86, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (86, 9), Dtype: float32)
#     [+] Group: demo_64
#         [-] Dataset: action (Shape: (93, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (93, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (93, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (93, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (93, 9), Dtype: float32)
#     [+] Group: demo_65
#         [-] Dataset: action (Shape: (63, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (63, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (63, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (63, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (63, 9), Dtype: float32)
#     [+] Group: demo_66
#         [-] Dataset: action (Shape: (74, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (74, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (74, 9), Dtype: float32)
#     [+] Group: demo_67
#         [-] Dataset: action (Shape: (86, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (86, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (86, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (86, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (86, 9), Dtype: float32)
#     [+] Group: demo_68
#         [-] Dataset: action (Shape: (67, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (67, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (67, 9), Dtype: float32)
#     [+] Group: demo_69
#         [-] Dataset: action (Shape: (70, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (70, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (70, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (70, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (70, 9), Dtype: float32)
#     [+] Group: demo_7
#         [-] Dataset: action (Shape: (67, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (67, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (67, 9), Dtype: float32)
#     [+] Group: demo_70
#         [-] Dataset: action (Shape: (108, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (108, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (108, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (108, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (108, 9), Dtype: float32)
#     [+] Group: demo_71
#         [-] Dataset: action (Shape: (89, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (89, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (89, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (89, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (89, 9), Dtype: float32)
#     [+] Group: demo_72
#         [-] Dataset: action (Shape: (71, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)
#     [+] Group: demo_73
#         [-] Dataset: action (Shape: (94, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (94, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (94, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (94, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (94, 9), Dtype: float32)
#     [+] Group: demo_74
#         [-] Dataset: action (Shape: (82, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (82, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (82, 9), Dtype: float32)
#     [+] Group: demo_75
#         [-] Dataset: action (Shape: (83, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (83, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (83, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (83, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (83, 9), Dtype: float32)
#     [+] Group: demo_76
#         [-] Dataset: action (Shape: (95, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (95, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (95, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (95, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (95, 9), Dtype: float32)
#     [+] Group: demo_77
#         [-] Dataset: action (Shape: (66, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (66, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (66, 9), Dtype: float32)
#     [+] Group: demo_78
#         [-] Dataset: action (Shape: (79, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (79, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (79, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (79, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (79, 9), Dtype: float32)
#     [+] Group: demo_79
#         [-] Dataset: action (Shape: (71, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (71, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (71, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (71, 9), Dtype: float32)
#     [+] Group: demo_8
#         [-] Dataset: action (Shape: (76, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (76, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (76, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (76, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (76, 9), Dtype: float32)
#     [+] Group: demo_80
#         [-] Dataset: action (Shape: (97, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (97, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (97, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (97, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (97, 9), Dtype: float32)
#     [+] Group: demo_81
#         [-] Dataset: action (Shape: (70, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (70, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (70, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (70, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (70, 9), Dtype: float32)
#     [+] Group: demo_82
#         [-] Dataset: action (Shape: (94, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (94, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (94, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (94, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (94, 9), Dtype: float32)
#     [+] Group: demo_83
#         [-] Dataset: action (Shape: (67, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (67, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (67, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (67, 9), Dtype: float32)
#     [+] Group: demo_84
#         [-] Dataset: action (Shape: (92, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (92, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (92, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (92, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (92, 9), Dtype: float32)
#     [+] Group: demo_85
#         [-] Dataset: action (Shape: (88, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (88, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (88, 9), Dtype: float32)
#     [+] Group: demo_86
#         [-] Dataset: action (Shape: (79, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (79, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (79, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (79, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (79, 9), Dtype: float32)
#     [+] Group: demo_87
#         [-] Dataset: action (Shape: (66, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (66, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (66, 9), Dtype: float32)
#     [+] Group: demo_88
#         [-] Dataset: action (Shape: (77, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (77, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (77, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (77, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (77, 9), Dtype: float32)
#     [+] Group: demo_89
#         [-] Dataset: action (Shape: (74, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (74, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (74, 9), Dtype: float32)
#     [+] Group: demo_9
#         [-] Dataset: action (Shape: (88, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (88, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (88, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (88, 9), Dtype: float32)
#     [+] Group: demo_90
#         [-] Dataset: action (Shape: (74, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (74, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (74, 9), Dtype: float32)
#     [+] Group: demo_91
#         [-] Dataset: action (Shape: (82, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (82, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (82, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (82, 9), Dtype: float32)
#     [+] Group: demo_92
#         [-] Dataset: action (Shape: (106, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (106, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (106, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (106, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (106, 9), Dtype: float32)
#     [+] Group: demo_93
#         [-] Dataset: action (Shape: (61, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (61, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (61, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (61, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (61, 9), Dtype: float32)
#     [+] Group: demo_94
#         [-] Dataset: action (Shape: (101, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (101, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (101, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (101, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (101, 9), Dtype: float32)
#     [+] Group: demo_95
#         [-] Dataset: action (Shape: (65, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (65, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (65, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (65, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (65, 9), Dtype: float32)
#     [+] Group: demo_96
#         [-] Dataset: action (Shape: (66, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (66, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (66, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (66, 9), Dtype: float32)
#     [+] Group: demo_97
#         [-] Dataset: action (Shape: (73, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (73, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (73, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (73, 9), Dtype: float32)
#     [+] Group: demo_98
#         [-] Dataset: action (Shape: (69, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (69, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (69, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (69, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (69, 9), Dtype: float32)
#     [+] Group: demo_99
#         [-] Dataset: action (Shape: (74, 8), Dtype: float64)
#         [+] Group: obs
#             [-] Dataset: ee_pose (Shape: (74, 7), Dtype: float32)
#             [-] Dataset: image_0 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: image_1 (Shape: (74, 256, 256, 3), Dtype: uint8)
#             [-] Dataset: qpos (Shape: (74, 9), Dtype: float32)
