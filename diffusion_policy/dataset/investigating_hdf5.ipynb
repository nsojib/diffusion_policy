# %%
import h5py
with h5py.File("/home/carl_lab/diffusion_policy/low_dim_v141.hdf5", "r") as f:
    raw_shape = f["data/demo_0/actions"].shape
    print(raw_shape)
# Out:
# (59, 7)

# %%
import h5py

file_path = "/home/carl_lab/diffusion_policy/low_dim_v141.hdf5"
with h5py.File(file_path, "r") as f:
    # pick one demo group
    demo = f["data"]["demo_0"]
    print(list(demo["obs"].keys()))
# Out:
# ['object', 'robot0_eef_pos', 'robot0_eef_quat', 'robot0_eef_vel_ang', 'robot0_eef_vel_lin', 'robot0_gripper_qpos', 'robot0_gripper_qvel', 'robot0_joint_pos', 'robot0_joint_pos_cos', 'robot0_joint_pos_sin', 'robot0_joint_vel']
